# %% [markdown]
# # Feature Engineering
#
# In this step we create new features that may help models capture liquidity behavior:
# - Moving averages of price (3-day, 5-day)
# - Price volatility (3-day std)
# - EMA of liquidity ratio

# %%
import pandas as pd
from pathlib import Path

BASE = Path.cwd().parent if Path.cwd().name=="notebooks" else Path.cwd()
DATA = BASE/"data"/"processed"/"merged_coin_gecko.csv"

df = pd.read_csv(DATA, parse_dates=["date"])
df.head()
# Out:
#        coin symbol         price     1h    24h     7d    24h_volume  \
# 0   Bitcoin    BTC  40859.460000  0.022  0.030  0.055  3.539076e+10
# 1  Ethereum    ETH   2744.410000  0.024  0.034  0.065  1.974870e+10
# 2    Tether   USDT      1.000000 -0.001 -0.001  0.000  5.793497e+10
# 3       BNB    BNB    383.430000  0.018  0.028  0.004  1.395854e+09
# 4  USD Coin   USDC      0.999874 -0.001  0.000 -0.000  3.872274e+09
#
#         mkt_cap       date                source_file  liquidity_ratio
# 0  7.709915e+11 2022-03-16  coin_gecko_2022-03-16.csv         0.045903
# 1  3.271044e+11 2022-03-16  coin_gecko_2022-03-16.csv         0.060374
# 2  7.996516e+10 2022-03-16  coin_gecko_2022-03-16.csv         0.724503
# 3  6.404382e+10 2022-03-16  coin_gecko_2022-03-16.csv         0.021795
# 4  5.222214e+10 2022-03-16  coin_gecko_2022-03-16.csv         0.074150

# %% [markdown]
# ### Add Engineered Features
# We add moving averages, volatility, and EMA features per coin.

# %%
df = df.sort_values(["coin","date"]).reset_index(drop=True)

# Rolling averages
df["price_ma_3"] = df.groupby("coin")["price"].transform(lambda s: s.rolling(3, min_periods=1).mean())
df["price_ma_5"] = df.groupby("coin")["price"].transform(lambda s: s.rolling(5, min_periods=1).mean())

# Volatility (3-day std)
df["vol_3d"] = df.groupby("coin")["price"].transform(lambda s: s.rolling(3, min_periods=2).std())

# EMA of liquidity ratio
df["lr_ema_3"] = df.groupby("coin")["liquidity_ratio"].transform(lambda s: s.ewm(span=3, adjust=False).mean())

df[["coin","price","price_ma_3","price_ma_5","vol_3d","liquidity_ratio","lr_ema_3"]].head(10)
# Out:
#            coin     price  price_ma_3  price_ma_5        vol_3d  \
# 0            0x  0.509791    0.509791    0.509791           NaN
# 1            0x  0.518160    0.513975    0.513975  5.917777e-03
# 2         1inch  1.500000    1.500000    1.500000           NaN
# 3         1inch  1.490000    1.495000    1.495000  7.071068e-03
# 4  AIOZ Network  0.237396    0.237396    0.237396           NaN
# 5  AIOZ Network  0.214561    0.225978    0.225978  1.614678e-02
# 6        APENFT  0.000002    0.000002    0.000002           NaN
# 7        APENFT  0.000002    0.000002    0.000002  1.080459e-08
# 8          API3  4.700000    4.700000    4.700000           NaN
# 9          API3  4.640000    4.670000    4.670000  4.242641e-02
#
#    liquidity_ratio  lr_ema_3
# 0         0.068490  0.068490
# 1         0.055165  0.061828
# 2         0.195501  0.195501
# 3         0.103878  0.149690
# 4         0.120092  0.120092
# 5         0.053256  0.086674
# 6         0.163760  0.163760
# 7         0.123973  0.143867
# 8         0.128719  0.128719
# 9         0.133236  0.130977

# %%
OUT = BASE/"data"/"processed"/"engineered_features.csv"
df.to_csv(OUT, index=False)
print("Saved:", OUT)
# Out:
# Saved: C:\Users\krpra\Desktop\Project\crypto_liquidity_project\data\processed\engineered_features.csv

# %%
import pandas as pd

df = df.sort_values(["coin","date"]).reset_index(drop=True)

# 1-day lags per coin (strictly past)
for col in ["liquidity_ratio","price","24h_volume","mkt_cap"]:
    if col in df.columns:
        df[f"{col}_lag1"] = df.groupby("coin")[col].shift(1)

# 1-day returns / changes from lags
df["price_ret_1d"] = (df["price"] - df["price_lag1"]) / df["price_lag1"]
df["vol_chg_1d"]   = (df["24h_volume"] - df["24h_volume_lag1"]) / df["24h_volume_lag1"]
df["mcap_chg_1d"]  = (df["mkt_cap"] - df["mkt_cap_lag1"]) / df["mkt_cap_lag1"]

# Fill inf with NaN, we will drop NaNs before modeling
for c in ["price_ret_1d","vol_chg_1d","mcap_chg_1d"]:
    if c in df.columns:
        df[c] = df[c].replace([pd.NA, pd.NaT, float("inf"), float("-inf")], pd.NA)

df.head(10)
# Out:
#            coin symbol     price     1h    24h     7d   24h_volume  \
# 0            0x    ZRX  0.509791  0.025  0.035  0.028   29309302.0
# 1            0x    ZRX  0.518160  0.003  0.016 -0.010   24224308.0
# 2         1inch  1INCH  1.500000  0.021  0.111  0.163  120457113.0
# 3         1inch  1INCH  1.490000  0.008 -0.003  0.087   64145152.0
# 4  AIOZ Network   AIOZ  0.237396  0.047  0.287  0.241   13715452.0
# 5  AIOZ Network   AIOZ  0.214561 -0.012 -0.095 -0.107    5493212.0
# 6        APENFT    NFT  0.000002  0.004  0.005 -0.047   69002807.0
# 7        APENFT    NFT  0.000002  0.001  0.010 -0.052   52887977.0
# 8          API3   API3  4.700000  0.028 -0.008 -0.101   29731985.0
# 9          API3   API3  4.640000  0.003 -0.012 -0.146   30688251.0
#
#        mkt_cap       date                source_file  ...  price_ma_5  \
# 0  427933388.0 2022-03-16  coin_gecko_2022-03-16.csv  ...    0.509791
# 1  439124277.0 2022-03-17  coin_gecko_2022-03-17.csv  ...    0.513975
# 2  616145134.0 2022-03-16  coin_gecko_2022-03-16.csv  ...    1.500000
# 3  617505356.0 2022-03-17  coin_gecko_2022-03-17.csv  ...    1.495000
# 4  114207956.0 2022-03-16  coin_gecko_2022-03-16.csv  ...    0.237396
# 5  103148149.0 2022-03-17  coin_gecko_2022-03-17.csv  ...    0.225978
# 6  421365369.0 2022-03-16  coin_gecko_2022-03-16.csv  ...    0.000002
# 7  426608620.0 2022-03-17  coin_gecko_2022-03-17.csv  ...    0.000002
# 8  230984150.0 2022-03-16  coin_gecko_2022-03-16.csv  ...    4.700000
# 9  230330587.0 2022-03-17  coin_gecko_2022-03-17.csv  ...    4.670000
#
#          vol_3d  lr_ema_3  liquidity_ratio_lag1  price_lag1  24h_volume_lag1  \
# 0           NaN  0.068490                   NaN         NaN              NaN
# 1  5.917777e-03  0.061828              0.068490    0.509791       29309302.0
# 2           NaN  0.195501                   NaN         NaN              NaN
# 3  7.071068e-03  0.149690              0.195501    1.500000      120457113.0
# 4           NaN  0.120092                   NaN         NaN              NaN
# 5  1.614678e-02  0.086674              0.120092    0.237396       13715452.0
# 6           NaN  0.163760                   NaN         NaN              NaN
# 7  1.080459e-08  0.143867              0.163760    0.000002       69002807.0
# 8           NaN  0.128719                   NaN         NaN              NaN
# 9  4.242641e-02  0.130977              0.128719    4.700000       29731985.0
#
#    mkt_cap_lag1  price_ret_1d  vol_chg_1d  mcap_chg_1d
# 0           NaN           NaN         NaN          NaN
# 1   427933388.0      0.016417   -0.173494     0.026151
# 2           NaN           NaN         NaN          NaN
# 3   616145134.0     -0.006667   -0.467486     0.002208
# 4           NaN           NaN         NaN          NaN
# 5   114207956.0     -0.096189   -0.599487    -0.096839
# 6           NaN           NaN         NaN          NaN
# 7   421365369.0      0.010029   -0.233539     0.012443
# 8           NaN           NaN         NaN          NaN
# 9   230984150.0     -0.012766    0.032163    -0.002829
#
# [10 rows x 22 columns]

# %%
import numpy as np

df["log_price"] = np.log1p(df["price"])
df["log_vol"]   = np.log1p(df["24h_volume"])
df["log_mcap"]  = np.log1p(df["mkt_cap"])

# %%
OUT_LAG = BASE/"data"/"processed"/"engineered_features_lag.csv"
df.to_csv(OUT_LAG, index=False)
print("Saved:", OUT_LAG)
# Out:
# Saved: C:\Users\krpra\Desktop\Project\crypto_liquidity_project\data\processed\engineered_features_lag.csv
